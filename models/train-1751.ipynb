# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import (
    roc_curve, auc, confusion_matrix, classification_report, accuracy_score
)
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

RANDOM_STATE = 42

# %% [markdown]
# ## 2. Load data
#
# Reads `huntingtons_ML_dataset_GSE1751.csv` — blood-derived microarray data
# (Affymetrix U133A, GPL96) comparing symptomatic HD patients against healthy
# controls. Presymptomatic HD gene-carriers were excluded during extraction.
#
# Column layout:
# - `Sample_ID` — GSM accession (identifier column, dropped from features)
# - `Huntingtons_Disease` — target column (1 = symptomatic HD, 0 = control)
# - gene-symbol columns — probe-averaged, same approach as the GSE3790 pipeline.

# %%
DATA_PATH = "../datasets/GSE1751_Huntington_dataset.csv"
ID_COL = "Sample_ID"
TARGET_COL = "Huntingtons_Disease"

df = pd.read_csv(DATA_PATH)
print(df.shape)
df.head()
# Out:
# (26, 13)
#   Sample_ID  Huntingtons_Disease  PPP1CC    IGF2BP3   CEBPD     YTHDC2    FTO  \
# 0  GSM30530                    1  1140.3  30.233333  290.55  55.033333  165.8
# 1  GSM30531                    1   647.6  20.100000  134.70  59.466667  178.0
# 2  GSM30532                    1  1091.6  15.066667  357.10  73.600000  178.8
# 3  GSM30533                    1  1000.8  23.633333  115.05  66.066667  139.5
# 4  GSM30534                    1  1075.7  32.433333  255.35  64.600000  160.6
#
#    YTHDC1   CEBPB  YTHDF2  METTL16  YTHDF1  YTHDF3
# 0  335.50  1758.3   277.0     21.4   417.4   296.2
# 1  227.60  1687.0   192.5     36.9   402.6   190.1
# 2  358.75  2268.6   262.2      8.5   340.5   355.9
# 3  235.40  1069.2   244.6     18.3   349.6   183.9
# 4  309.45  1664.3   199.2     25.7   264.0   150.6

# %%
feature_cols = [c for c in df.columns if c not in (ID_COL, TARGET_COL)]

X = df[feature_cols]
y = df[TARGET_COL]

print(f"Samples: {X.shape[0]}, Features: {X.shape[1]}")
print("Features:", feature_cols)
print("\nClass balance:")
print(y.value_counts())
# Out:
# Samples: 26, Features: 11
# Features: ['PPP1CC', 'IGF2BP3', 'CEBPD', 'YTHDC2', 'FTO', 'YTHDC1', 'CEBPB', 'YTHDF2', 'METTL16', 'YTHDF1', 'YTHDF3']
#
# Class balance:
# Huntingtons_Disease
# 0    14
# 1    12
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Impute + scale

# %%
X_imputed = SimpleImputer(strategy="mean").fit_transform(X)
X_scaled = StandardScaler().fit_transform(X_imputed)

# %% [markdown]
# ## 4. Train/test split
#
# Stratified so both classes are represented in the test set. GSE1751 is a
# smaller cohort (~26 samples) than GSE64810, so check the printed class
# counts below before trusting the results.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y
)

print("Train class balance:")
print(y_train.value_counts())
print("\nTest class balance:")
print(y_test.value_counts())
# Out:
# Train class balance:
# Huntingtons_Disease
# 0    11
# 1     9
# Name: count, dtype: int64
#
# Test class balance:
# Huntingtons_Disease
# 1    3
# 0    3
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Models + hyperparameter grids

# %%
models = {
    "SVM": {
        "model": SVC(probability=True, random_state=RANDOM_STATE),
        "params": {
            "C": [0.1, 1, 10],
            "kernel": ["linear", "rbf"],
        },
    },
    "GLM": {
        "model": LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
        "params": {
            "C": [0.1, 1, 10],
            "penalty": ["l2"],
        },
    },
    "RandomForest": {
        "model": RandomForestClassifier(random_state=RANDOM_STATE),
        "params": {
            "n_estimators": [100, 200, 300, 400],
            "max_depth": [1 ,2 , 3, 5],
            "min_samples_split": [2, 5],
            "min_samples_leaf": [1, 2],
        },
    },
    "XGBoost": {
        "model": XGBClassifier(
            eval_metric="logloss",
            random_state=RANDOM_STATE,
        ),
        "params": {
            "n_estimators": [100, 200, 400],
            "max_depth": [2, 3, 5],
            "learning_rate": [0.01, 0.05, 0.1],
            "subsample": [0.8, 1.0],
        },
    },
}

# %% [markdown]
# ## 6. GridSearchCV for each model
#
# Uses `StratifiedKFold` so class balance is preserved in every fold.
# `n_splits` is capped at the smallest class count in the training set so
# GridSearchCV doesn't fail on a fold with zero positive examples.

# %%
best_models = {}
roc_data = {}

min_class_count = y_train.value_counts().min()
print(f"Min class split {min_class_count}")
n_splits = max(2, min(5, min_class_count))
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_STATE)
print(f"Using {n_splits}-fold StratifiedKFold for GridSearchCV")
# Out:
# Min class split 9
# Using 5-fold StratifiedKFold for GridSearchCV

# %%
for name, mp in models.items():
    clf = GridSearchCV(
        mp["model"], mp["params"], cv=cv, scoring="roc_auc", n_jobs=-1
    )
    clf.fit(X_train, y_train)

    best_models[name] = clf.best_estimator_

    y_prob = clf.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)
    roc_data[name] = (fpr, tpr, roc_auc)

    print(f"Best {name} params: {clf.best_params_}")
    print(f"  CV best ROC-AUC: {clf.best_score_:.4f}  |  Test ROC-AUC: {roc_auc:.4f}")
# Out:
# Best SVM params: {'C': 0.1, 'kernel': 'linear'}
#   CV best ROC-AUC: 1.0000  |  Test ROC-AUC: 1.0000
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/cfg4040b/miniconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Best GLM params: {'C': 0.1, 'penalty': 'l2'}
#   CV best ROC-AUC: 1.0000  |  Test ROC-AUC: 1.0000
# Best RandomForest params: {'max_depth': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
#   CV best ROC-AUC: 1.0000  |  Test ROC-AUC: 1.0000
# Best XGBoost params: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8}
#   CV best ROC-AUC: 1.0000  |  Test ROC-AUC: 1.0000

# %% [markdown]
# ## 7. ROC curve comparison

# %%
plt.figure(figsize=(8, 6))
for name, (fpr, tpr, roc_auc) in roc_data.items():
    plt.plot(fpr, tpr, label=f"{name} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], "k--", label="Chance")
plt.xlabel("1 - Specificity (False Positive Rate)")
plt.ylabel("Sensitivity (True Positive Rate)")
plt.title("ROC Curve Comparison - GSE1751")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## 8. Detailed evaluation per model
#
# Accuracy, confusion matrix, and classification report for each tuned model
# on the held-out test set.

# %%
def evaluate_model(model, X_test, y_test, model_name):
    y_pred = model.predict(X_test)

    print(f"{'='*20}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*20}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    print(f"True Negatives (TN): {tn}")
    print(f"False Positives (FP): {fp}")
    print(f"False Negatives (FN): {fn}")
    print(f"True Positives (TP): {tp}")

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, zero_division=0))

    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix: {model_name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()


for name, model in best_models.items():
    evaluate_model(model, X_test, y_test, name)
# Out:
# ====================
# EVALUATION: SVM
# ====================
# Accuracy: 1.0000
# True Negatives (TN): 3
# False Positives (FP): 0
# False Negatives (FN): 0
# True Positives (TP): 3
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
# ====================
# EVALUATION: GLM
# ====================
# Accuracy: 1.0000
# True Negatives (TN): 3
# False Positives (FP): 0
# False Negatives (FN): 0
# True Positives (TP): 3
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
# ====================
# EVALUATION: RandomForest
# ====================
# Accuracy: 1.0000
# True Negatives (TN): 3
# False Positives (FP): 0
# False Negatives (FN): 0
# True Positives (TP): 3
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
# ====================
# EVALUATION: XGBoost
# ====================
# Accuracy: 1.0000
# True Negatives (TN): 3
# False Positives (FP): 0
# False Negatives (FN): 0
# True Positives (TP): 3
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %% [markdown]
# ## 9. Feature importance (RandomForest & XGBoost)
#
# Which of the 12 m6A biomarkers are actually driving predictions in this
# blood-derived microarray cohort.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, name in zip(axes, ["RandomForest", "XGBoost"]):
    model = best_models[name]
    importances = pd.Series(model.feature_importances_, index=feature_cols)
    importances = importances.sort_values(ascending=True)
    importances.plot(kind="barh", ax=ax)
    ax.set_title(f"{name} Feature Importances")

plt.tight_layout()
plt.show()

# %%
missing_markers = [g for g in MARKERS if g not in feature_cols] if "MARKERS" in dir() else []
print("Genes present in this dataset:", feature_cols)
print("Count:", len(feature_cols))
# Out:
# Genes present in this dataset: ['PPP1CC', 'IGF2BP3', 'CEBPD', 'YTHDC2', 'FTO', 'YTHDC1', 'CEBPB', 'YTHDF2', 'METTL16', 'YTHDF1', 'YTHDF3']
# Count: 11

# %% [markdown]
# ## 10. Per-gene ROC curves (individually trained single-feature models)
#
# For each available biomarker gene, a **separate Logistic Regression
# model is trained using only that one gene as its input feature**. Predictions
# are made using `cross_val_predict` with the same `StratifiedKFold` scheme used
# for the multivariate models in Section 6, so every sample gets an out-of-fold
# predicted probability (i.e. the model never sees a sample's own label when
# predicting it) — this is a real trained-model ROC curve per gene, not just a
# raw-value threshold sweep.

# %%
from sklearn.model_selection import cross_val_predict

gene_roc_data = {}
gene_models = {}

gene_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_STATE)

for gene in feature_cols:
    # Single-feature input: reshape to (n_samples, 1)
    gene_X = X[[gene]].values
    gene_X_imputed = SimpleImputer(strategy="mean").fit_transform(gene_X)
    gene_X_scaled = StandardScaler().fit_transform(gene_X_imputed)

    model = LogisticRegression(max_iter=1000, random_state=RANDOM_STATE)

    # Out-of-fold predicted probabilities: each sample's prediction comes from
    # a model that was NOT trained on that sample
    y_prob = cross_val_predict(
        model, gene_X_scaled, y, cv=gene_cv, method="predict_proba"
    )[:, 1]

    fpr, tpr, _ = roc_curve(y, y_prob)
    gene_auc = auc(fpr, tpr)
    gene_roc_data[gene] = (fpr, tpr, gene_auc)

    # Also fit on the full data for reference (e.g. if you want coefficients later)
    gene_models[gene] = model.fit(gene_X_scaled, y)

# Sort genes by AUC (distance from 0.5, since a gene could be predictive in
# either direction depending on whether it's up- or down-regulated in HD)
gene_roc_data = dict(
    sorted(gene_roc_data.items(), key=lambda kv: abs(kv[1][2] - 0.5), reverse=True)
)

print("Per-gene AUC (individually trained single-feature Logistic Regression, cross-validated):")
for gene, (_, _, gene_auc) in gene_roc_data.items():
    print(f"  {gene}: AUC = {gene_auc:.3f}")
# Out:
# Per-gene AUC (individually trained single-feature Logistic Regression, cross-validated):
#   YTHDF3: AUC = 1.000
#   PPP1CC: AUC = 0.976
#   YTHDC2: AUC = 0.952
#   YTHDC1: AUC = 0.917
#   YTHDF2: AUC = 0.756
#   YTHDF1: AUC = 0.286
#   FTO: AUC = 0.304
#   METTL16: AUC = 0.339
#   CEBPD: AUC = 0.405
#   CEBPB: AUC = 0.554
#   IGF2BP3: AUC = 0.470

# %% [markdown]
# ### 10a. All genes overlaid on one plot

# %%
plt.figure(figsize=(9, 7))
for gene, (fpr, tpr, gene_auc) in gene_roc_data.items():
    plt.plot(fpr, tpr, label=f"{gene} (AUC = {gene_auc:.2f})")

plt.plot([0, 1], [0, 1], "k--", label="Chance")
plt.xlabel("1 - Specificity (False Positive Rate)")
plt.ylabel("Sensitivity (True Positive Rate)")
plt.title("Per-Gene ROC Curves - GSE1751 (individually trained models)")
plt.legend(loc="lower right", fontsize=8)
plt.show()

# %% [markdown]
# ### 10b. Individual small-multiple panels (one subplot per gene)

# %%
n_genes = len(gene_roc_data)
n_cols = 4
n_rows = -(-n_genes // n_cols)  # ceiling division

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 3.5 * n_rows))
axes = axes.flatten()

for ax, (gene, (fpr, tpr, gene_auc)) in zip(axes, gene_roc_data.items()):
    ax.plot(fpr, tpr, color="tab:blue")
    ax.plot([0, 1], [0, 1], "k--", linewidth=0.8)
    ax.set_title(f"{gene} (AUC = {gene_auc:.2f})", fontsize=10)
    ax.set_xlabel("1 - Specificity")
    ax.set_ylabel("Sensitivity")

# Hide any unused subplot axes
for ax in axes[n_genes:]:
    ax.axis("off")

plt.tight_layout()
plt.show()
